# %%
# %pip install gurobipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 27.1 MB/s  0:00:00m0:00:010:01
# ...
# Note: you may need to restart the kernel to use updated packages.
